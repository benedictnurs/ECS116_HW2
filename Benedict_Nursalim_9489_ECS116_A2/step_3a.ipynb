# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, text as sql_text, inspect
import json
import os
import pprint
from datetime import datetime
import time

# Ensure 'perf_data' directory exists
os.makedirs('perf_data', exist_ok=True)

# Connect to the database
db_eng = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/airbnb',
                       connect_args={'options': '-csearch_path={}'.format('new_york_city')},
                       isolation_level='SERIALIZABLE')

# Modify the reviews table within the same connection block
with db_eng.connect() as conn:
    alter_table_query = """
    ALTER TABLE reviews
    ADD COLUMN datetime TIMESTAMP;
    """
    update_table_query = """
    UPDATE reviews
    SET datetime = TO_TIMESTAMP((TO_CHAR(date, 'YYYY-MM-DD') || ' 12:00:00'), 'YYYY-MM-DD hh24:mi:ss')::timestamp without time zone;
    """
    conn.execute(sql_text(alter_table_query))
    conn.execute(sql_text(update_table_query))
    conn.commit()  # Ensure the changes are committed
    
    # Check if the column 'datetime' exists
    inspector = inspect(conn)
    columns = [col['name'] for col in inspector.get_columns('reviews')]
    if 'datetime' in columns:
        print("'datetime' column successfully added.")
    else:
        print("'datetime' column was not added.")
        exit()

# Function to build query for listings join reviews with datetime
def build_query_listings_reviews(date_start, date_end):
    query = f"""
    SELECT DISTINCT l.id, l.name
    FROM listings l, reviews r 
    WHERE l.id = r.listing_id
      AND r.datetime >= '{date_start}'
      AND r.datetime <= '{date_end}'
    ORDER BY l.id;
    """
    return query
# Out:
# 'datetime' column successfully added.

# %%
# Function to add or drop index and fetch current indexes on the table
def add_drop_index(engine, action, column, table):
    index_name = f"idx_{column}_in_{table}"
    if action == 'add':
        query = sql_text(f"CREATE INDEX {index_name} ON {table}({column});")
    elif action == 'drop':
        query = sql_text(f"DROP INDEX IF EXISTS {index_name};")
    with engine.connect() as conn:
        conn.execute(query)

# Function to calculate time difference
def time_diff(start_time, end_time):
    return (end_time - start_time).total_seconds()

# Function to execute a query and measure time
def run_query(query, conn):
    times = []
    for _ in range(2):
        start_time = datetime.now()
        conn.execute(sql_text(query))
        end_time = datetime.now()
        times.append(time_diff(start_time, end_time))
    return times

# Function to compute performance metrics
def compute_metrics(times):
    return {
        "avg": round(np.mean(times), 4),
        "min": round(np.min(times), 4),
        "max": round(np.max(times), 4),
        "std": round(np.std(times), 4),
        "exec_count": len(times),
        "timestamp": datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    }

# Function to build the index description key
def build_index_description_key(all_indexes, spec):
    description_key = ""
    for index in all_indexes:
        if index in spec:
            description_key += f"__{index[0]}_in_{index[1]}"
    description_key += "__"
    return description_key

# Fetch performance data
def fetch_perf_data(filename):
    try:
        with open(filename) as f:
            if os.stat(filename).st_size == 0:
                return {}
            return json.load(f)
    except FileNotFoundError:
        return {}

# Write performance data
def write_perf_data(data, filename):
    with open(filename, 'w') as fp:
        json.dump(data, fp, indent=4)

# Create queries for each year from 2009 to 2024
q_dict = {}
for yr in range(2009, 2025):
    q_name = 'listings_join_review_' + str(yr)
    date_start = str(yr) + '-01-01 00:00:00'
    date_end = str(yr) + '-12-31 23:59:59'
    q_dict[q_name] = build_query_listings_reviews(date_start, date_end)

pprint.pp(q_dict)

perf_summary_path = 'perf_data/listings_join_reviews.json'
if not os.path.exists(perf_summary_path):
    with open(perf_summary_path, 'w') as f:
        json.dump({}, f)

perf_summary = fetch_perf_data(perf_summary_path)

all_indexes = [['datetime','reviews'], ['id','listings']]
specs = [
    [['datetime','reviews'], ['id','listings']],
    [['datetime','reviews']],
    [['id','listings']],
    []
]

for query_name, query in q_dict.items():
    for spec in specs:
        print('Processing spec: ', str(spec), '\n')

        for index in all_indexes:
            if index not in spec:
                add_drop_index(db_eng, 'drop', index[0], index[1])
                print('\nAfter dropping', str(index))

        for index in spec:
            add_drop_index(db_eng, 'add', index[0], index[1])
            print('\nAfter adding', str(index))

        time_list = []
        for i in range(50):
            with db_eng.connect() as conn:
                times = run_query(query, conn)
            time_list.extend(times)
        
        perf_profile = compute_metrics(time_list)

        print('\nThe list of running times is as follows:')
        pprint.pp(time_list)

        print('\nThe statistics on the list of running times are as follows:')
        pprint.pp(perf_profile)

        key_value = build_index_description_key(all_indexes, spec)
        print('\nThe new value for "' + key_value + '" will be', str(perf_profile))

        if query_name in perf_summary:
            perf_dict = perf_summary[query_name]
            print("\nBefore modifying perf_dict, the value of perf_summary[query_name] (if it existed) was: ")
            pprint.pp(perf_dict)
        else:
            perf_dict = {}
            print("\nBefore modifying perf_dict, the value of perf_summary[query_name] had empty value")
        print()
        perf_dict[key_value] = perf_profile
        perf_summary[query_name] = perf_dict

        print("\nAfter modifying perf_dict, the value of perf_summary[query_name] is: ")
        pprint.pp(perf_summary[query_name])
        print()

        print('\nThe full value of perf_summary is:')
        pprint.pp(perf_summary)

        write_perf_data(perf_summary, perf_summary_path)

print("JSON files created successfully.")
# Out:
# {'listings_join_review_2009': '\n'
#                               '    SELECT DISTINCT l.id, l.name\n'
#                               '    FROM listings l, reviews r \n'
#                               '    WHERE l.id = r.listing_id\n'
#                               "      AND r.datetime >= '2009-01-01 00:00:00'\n"
#                               "      AND r.datetime <= '2009-12-31 23:59:59'\n"
#                               '    ORDER BY l.id;\n'
#                               '    ',
#  'listings_join_review_2010': '\n'
#                               '    SELECT DISTINCT l.id, l.name\n'
#                               '    FROM listings l, reviews r \n'
#                               '    WHERE l.id = r.listing_id\n'
#                               "      AND r.datetime >= '2010-01-01 00:00:00'\n"
#                               "      AND r.datetime <= '2010-12-31 23:59:59'\n"
#                               '    ORDER BY l.id;\n'
#                               '    ',
#  'listings_join_review_2011': '\n'
#                               '    SELECT DISTINCT l.id, l.name\n'
#                               '    FROM listings l, reviews r \n'
#                               '    WHERE l.id = r.listing_id\n'
#                               "      AND r.datetime >= '2011-01-01 00:00:00'\n"
#                               "      AND r.datetime <= '2011-12-31 23:59:59'\n"
#                               '    ORDER BY l.id;\n'
#                               '    ',
#  'listings_join_review_2012': '\n'
#                               '    SELECT DISTINCT l.id, l.name\n'
#                               '    FROM listings l, reviews r \n'
#                               '    WHERE l.id = r.listing_id\n'
#                               "      AND r.datetime >= '2012-01-01 00:00:00'\n"
#                               "      AND r.datetime <= '2012-12-31 23:59:59'\n"
#                               '    ORDER BY l.id;\n'
#                               '    ',
#  'listings_join_review_2013': '\n'
#                               '    SELECT DISTINCT l.id, l.name\n'
#                               '    FROM listings l, reviews r \n'
#                               '    WHERE l.id = r.listing_id\n'
#                               "      AND r.datetime >= '2013-01-01 00:00:00'\n"
#                               "      AND r.datetime <= '2013-12-31 23:59:59'\n"
#                               '    ORDER BY l.id;\n'
#                               '    ',
#  'listings_join_review_2014': '\n'
#                               '    SELECT DISTINCT l.id, l.name\n'
#                               '    FROM listings l, reviews r \n'
#                               '    WHERE l.id = r.listing_id\n'
#                               "      AND r.datetime >= '2014-01-01 00:00:00'\n"
#                               "      AND r.datetime <= '2014-12-31 23:59:59'\n"
#                               '    ORDER BY l.id;\n'
#                               '    ',
#  'listings_join_review_2015': '\n'
#                               '    SELECT DISTINCT l.id, l.name\n'
#                               '    FROM listings l, reviews r \n'
#                               '    WHERE l.id = r.listing_id\n'
#                               "      AND r.datetime >= '2015-01-01 00:00:00'\n"
#                               "      AND r.datetime <= '2015-12-31 23:59:59'\n"
#                               '    ORDER BY l.id;\n'
#                               '    ',
#  'listings_join_review_2016': '\n'
#                               '    SELECT DISTINCT l.id, l.name\n'
#                               '    FROM listings l, reviews r \n'
#                               '    WHERE l.id = r.listing_id\n'
#                               "      AND r.datetime >= '2016-01-01 00:00:00'\n"
#                               "      AND r.datetime <= '2016-12-31 23:59:59'\n"
#                               '    ORDER BY l.id;\n'
#                               '    ',
#  'listings_join_review_2017': '\n'
#                               '    SELECT DISTINCT l.id, l.name\n'
#                               '    FROM listings l, reviews r \n'
#                               '    WHERE l.id = r.listing_id\n'
#                               "      AND r.datetime >= '2017-01-01 00:00:00'\n"
#                               "      AND r.datetime <= '2017-12-31 23:59:59'\n"
#                               '    ORDER BY l.id;\n'
#                               '    ',
#  'listings_join_review_2018': '\n'
#                               '    SELECT DISTINCT l.id, l.name\n'
#                               '    FROM listings l, reviews r \n'
#                               '    WHERE l.id = r.listing_id\n'
#                               "      AND r.datetime >= '2018-01-01 00:00:00'\n"
#                               "      AND r.datetime <= '2018-12-31 23:59:59'\n"
#                               '    ORDER BY l.id;\n'
#                               '    ',
#  'listings_join_review_2019': '\n'
#                               '    SELECT DISTINCT l.id, l.name\n'
#                               '    FROM listings l, reviews r \n'
#                               '    WHERE l.id = r.listing_id\n'
#                               "      AND r.datetime >= '2019-01-01 00:00:00'\n"
#                               "      AND r.datetime <= '2019-12-31 23:59:59'\n"
#                               '    ORDER BY l.id;\n'
#                               '    ',
#  'listings_join_review_2020': '\n'
#                               '    SELECT DISTINCT l.id, l.name\n'
#                               '    FROM listings l, reviews r \n'
#                               '    WHERE l.id = r.listing_id\n'
#                               "      AND r.datetime >= '2020-01-01 00:00:00'\n"
#                               "      AND r.datetime <= '2020-12-31 23:59:59'\n"
#                               '    ORDER BY l.id;\n'
#                               '    ',
#  'listings_join_review_2021': '\n'
#                               '    SELECT DISTINCT l.id, l.name\n'
#                               '    FROM listings l, reviews r \n'
#                               '    WHERE l.id = r.listing_id\n'
#                               "      AND r.datetime >= '2021-01-01 00:00:00'\n"
#                               "      AND r.datetime <= '2021-12-31 23:59:59'\n"
#                               '    ORDER BY l.id;\n'
#                               '    ',
#  'listings_join_review_2022': '\n'
#                               '    SELECT DISTINCT l.id, l.name\n'
#                               '    FROM listings l, reviews r \n'
#                               '    WHERE l.id = r.listing_id\n'
#                               "      AND r.datetime >= '2022-01-01 00:00:00'\n"
#                               "      AND r.datetime <= '2022-12-31 23:59:59'\n"
#                               '    ORDER BY l.id;\n'
#                               '    ',
#  'listings_join_review_2023': '\n'
#                               '    SELECT DISTINCT l.id, l.name\n'
#                               '    FROM listings l, reviews r \n'
#                               '    WHERE l.id = r.listing_id\n'
#                               "      AND r.datetime >= '2023-01-01 00:00:00'\n"
#                               "      AND r.datetime <= '2023-12-31 23:59:59'\n"
#                               '    ORDER BY l.id;\n'
#                               '    ',
#  'listings_join_review_2024': '\n'
#                               '    SELECT DISTINCT l.id, l.name\n'
#                               '    FROM listings l, reviews r \n'
#                               '    WHERE l.id = r.listing_id\n'
#                               "      AND r.datetime >= '2024-01-01 00:00:00'\n"
#                               "      AND r.datetime <= '2024-12-31 23:59:59'\n"
#                               '    ORDER BY l.id;\n'
#                               '    '}
# Processing spec:  [['datetime', 'reviews'], ['id', 'listings']]
#
#
# After adding ['datetime', 'reviews']
#
# After adding ['id', 'listings']
#
# The list of running times is as follows:
# [0.704303, 0.637578]
#
# The statistics on the list of running times are as follows:
# {'avg': 0.6709,
#  'min': 0.6376,
#  'max': 0.7043,
#  'std': 0.0334,
#  'exec_count': 2,
#  'timestamp': '2024-05-21 13:16:24'}
#
# The new value for "__datetime_in_reviews__id_in_listings__" will be {'avg': 0.6709, 'min': 0.6376, 'max': 0.7043, 'std': 0.0334, 'exec_count': 2, 'timestamp': '2024-05-21 13:16:24'}
#
# Before modifying perf_dict, the value of perf_summary[query_name] had empty value
#
#
# After modifying perf_dict, the value of perf_summary[query_name] is:
# {'__datetime_in_reviews__id_in_listings__': {'avg': 0.6709,
#                                              'min': 0.6376,
#                                              'max': 0.7043,
#                                              'std': 0.0334,
#                                              'exec_count': 2,
#                                              'timestamp': '2024-05-21 '
#                                                           '13:16:24'}}
#
#
# The full value of perf_summary is:
# {'listings_join_review_2009': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.6709,
#                                                                            'min': 0.6376,
#                                                                            'max': 0.7043,
#                                                                            'std': 0.0334,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:24'}}}
# Processing spec:  [['datetime', 'reviews']]
#
#
# After dropping ['id', 'listings']
#
# After adding ['datetime', 'reviews']
#
# The list of running times is as follows:
# [0.128766, 0.078422]
#
# The statistics on the list of running times are as follows:
# {'avg': 0.1036,
#  'min': 0.0784,
#  'max': 0.1288,
#  'std': 0.0252,
#  'exec_count': 2,
#  'timestamp': '2024-05-21 13:16:25'}
#
# The new value for "__datetime_in_reviews__" will be {'avg': 0.1036, 'min': 0.0784, 'max': 0.1288, 'std': 0.0252, 'exec_count': 2, 'timestamp': '2024-05-21 13:16:25'}
#
# Before modifying perf_dict, the value of perf_summary[query_name] (if it existed) was:
# {'__datetime_in_reviews__id_in_listings__': {'avg': 0.6709,
#                                              'min': 0.6376,
#                                              'max': 0.7043,
#                                              'std': 0.0334,
#                                              'exec_count': 2,
#                                              'timestamp': '2024-05-21 '
#                                                           '13:16:24'}}
#
#
# After modifying perf_dict, the value of perf_summary[query_name] is:
# {'__datetime_in_reviews__id_in_listings__': {'avg': 0.6709,
#                                              'min': 0.6376,
#                                              'max': 0.7043,
#                                              'std': 0.0334,
#                                              'exec_count': 2,
#                                              'timestamp': '2024-05-21 '
#                                                           '13:16:24'},
#  '__datetime_in_reviews__': {'avg': 0.1036,
#                              'min': 0.0784,
#                              'max': 0.1288,
#                              'std': 0.0252,
#                              'exec_count': 2,
#                              'timestamp': '2024-05-21 13:16:25'}}
#
#
# The full value of perf_summary is:
# {'listings_join_review_2009': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.6709,
#                                                                            'min': 0.6376,
#                                                                            'max': 0.7043,
#                                                                            'std': 0.0334,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:24'},
#                                '__datetime_in_reviews__': {'avg': 0.1036,
#                                                            'min': 0.0784,
#                                                            'max': 0.1288,
#                                                            'std': 0.0252,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:25'}}}
# Processing spec:  [['id', 'listings']]
#
#
# After dropping ['datetime', 'reviews']
#
# After adding ['id', 'listings']
#
# The list of running times is as follows:
# [0.073748, 0.086454]
#
# The statistics on the list of running times are as follows:
# {'avg': 0.0801,
#  'min': 0.0737,
#  'max': 0.0865,
#  'std': 0.0064,
#  'exec_count': 2,
#  'timestamp': '2024-05-21 13:16:26'}
#
# The new value for "__id_in_listings__" will be {'avg': 0.0801, 'min': 0.0737, 'max': 0.0865, 'std': 0.0064, 'exec_count': 2, 'timestamp': '2024-05-21 13:16:26'}
#
# Before modifying perf_dict, the value of perf_summary[query_name] (if it existed) was:
# {'__datetime_in_reviews__id_in_listings__': {'avg': 0.6709,
#                                              'min': 0.6376,
#                                              'max': 0.7043,
#                                              'std': 0.0334,
#                                              'exec_count': 2,
#                                              'timestamp': '2024-05-21 '
#                                                           '13:16:24'},
#  '__datetime_in_reviews__': {'avg': 0.1036,
#                              'min': 0.0784,
#                              'max': 0.1288,
#                              'std': 0.0252,
#                              'exec_count': 2,
#                              'timestamp': '2024-05-21 13:16:25'}}
#
#
# After modifying perf_dict, the value of perf_summary[query_name] is:
# {'__datetime_in_reviews__id_in_listings__': {'avg': 0.6709,
#                                              'min': 0.6376,
#                                              'max': 0.7043,
#                                              'std': 0.0334,
#                                              'exec_count': 2,
#                                              'timestamp': '2024-05-21 '
#                                                           '13:16:24'},
#  '__datetime_in_reviews__': {'avg': 0.1036,
#                              'min': 0.0784,
#                              'max': 0.1288,
#                              'std': 0.0252,
#                              'exec_count': 2,
#                              'timestamp': '2024-05-21 13:16:25'},
#  '__id_in_listings__': {'avg': 0.0801,
#                         'min': 0.0737,
#                         'max': 0.0865,
#                         'std': 0.0064,
#                         'exec_count': 2,
#                         'timestamp': '2024-05-21 13:16:26'}}
#
#
# The full value of perf_summary is:
# {'listings_join_review_2009': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.6709,
#                                                                            'min': 0.6376,
#                                                                            'max': 0.7043,
#                                                                            'std': 0.0334,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:24'},
#                                '__datetime_in_reviews__': {'avg': 0.1036,
#                                                            'min': 0.0784,
#                                                            'max': 0.1288,
#                                                            'std': 0.0252,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:25'},
#                                '__id_in_listings__': {'avg': 0.0801,
#                                                       'min': 0.0737,
#                                                       'max': 0.0865,
#                                                       'std': 0.0064,
#                                                       'exec_count': 2,
#                                                       'timestamp': '2024-05-21 '
#                                                                    '13:16:26'}}}
# Processing spec:  []
#
#
# After dropping ['datetime', 'reviews']
#
# After dropping ['id', 'listings']
#
# The list of running times is as follows:
# [0.07633, 0.075607]
#
# The statistics on the list of running times are as follows:
# {'avg': 0.076,
#  'min': 0.0756,
#  'max': 0.0763,
#  'std': 0.0004,
#  'exec_count': 2,
#  'timestamp': '2024-05-21 13:16:26'}
#
# The new value for "__" will be {'avg': 0.076, 'min': 0.0756, 'max': 0.0763, 'std': 0.0004, 'exec_count': 2, 'timestamp': '2024-05-21 13:16:26'}
#
# Before modifying perf_dict, the value of perf_summary[query_name] (if it existed) was:
# {'__datetime_in_reviews__id_in_listings__': {'avg': 0.6709,
#                                              'min': 0.6376,
#                                              'max': 0.7043,
#                                              'std': 0.0334,
#                                              'exec_count': 2,
#                                              'timestamp': '2024-05-21 '
#                                                           '13:16:24'},
#  '__datetime_in_reviews__': {'avg': 0.1036,
#                              'min': 0.0784,
#                              'max': 0.1288,
#                              'std': 0.0252,
#                              'exec_count': 2,
#                              'timestamp': '2024-05-21 13:16:25'},
#  '__id_in_listings__': {'avg': 0.0801,
#                         'min': 0.0737,
#                         'max': 0.0865,
#                         'std': 0.0064,
#                         'exec_count': 2,
#                         'timestamp': '2024-05-21 13:16:26'}}
#
#
# After modifying perf_dict, the value of perf_summary[query_name] is:
# {'__datetime_in_reviews__id_in_listings__': {'avg': 0.6709,
#                                              'min': 0.6376,
#                                              'max': 0.7043,
#                                              'std': 0.0334,
#                                              'exec_count': 2,
#                                              'timestamp': '2024-05-21 '
#                                                           '13:16:24'},
#  '__datetime_in_reviews__': {'avg': 0.1036,
#                              'min': 0.0784,
#                              'max': 0.1288,
#                              'std': 0.0252,
#                              'exec_count': 2,
#                              'timestamp': '2024-05-21 13:16:25'},
#  '__id_in_listings__': {'avg': 0.0801,
#                         'min': 0.0737,
#                         'max': 0.0865,
#                         'std': 0.0064,
#                         'exec_count': 2,
#                         'timestamp': '2024-05-21 13:16:26'},
#  '__': {'avg': 0.076,
#         'min': 0.0756,
#         'max': 0.0763,
#         'std': 0.0004,
#         'exec_count': 2,
#         'timestamp': '2024-05-21 13:16:26'}}
#
#
# The full value of perf_summary is:
# {'listings_join_review_2009': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.6709,
#                                                                            'min': 0.6376,
#                                                                            'max': 0.7043,
#                                                                            'std': 0.0334,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:24'},
#                                '__datetime_in_reviews__': {'avg': 0.1036,
#                                                            'min': 0.0784,
#                                                            'max': 0.1288,
#                                                            'std': 0.0252,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:25'},
#                                '__id_in_listings__': {'avg': 0.0801,
#                                                       'min': 0.0737,
#                                                       'max': 0.0865,
#                                                       'std': 0.0064,
#                                                       'exec_count': 2,
#                                                       'timestamp': '2024-05-21 '
#                                                                    '13:16:26'},
#                                '__': {'avg': 0.076,
#                                       'min': 0.0756,
#                                       'max': 0.0763,
#                                       'std': 0.0004,
#                                       'exec_count': 2,
#                                       'timestamp': '2024-05-21 13:16:26'}}}
# Processing spec:  [['datetime', 'reviews'], ['id', 'listings']]
#
#
# After adding ['datetime', 'reviews']
#
# After adding ['id', 'listings']
#
# The list of running times is as follows:
# [0.074726, 0.074368]
#
# The statistics on the list of running times are as follows:
# {'avg': 0.0745,
#  'min': 0.0744,
#  'max': 0.0747,
#  'std': 0.0002,
#  'exec_count': 2,
#  'timestamp': '2024-05-21 13:16:26'}
#
# The new value for "__datetime_in_reviews__id_in_listings__" will be {'avg': 0.0745, 'min': 0.0744, 'max': 0.0747, 'std': 0.0002, 'exec_count': 2, 'timestamp': '2024-05-21 13:16:26'}
#
# Before modifying perf_dict, the value of perf_summary[query_name] had empty value
#
#
# After modifying perf_dict, the value of perf_summary[query_name] is:
# {'__datetime_in_reviews__id_in_listings__': {'avg': 0.0745,
#                                              'min': 0.0744,
#                                              'max': 0.0747,
#                                              'std': 0.0002,
#                                              'exec_count': 2,
#                                              'timestamp': '2024-05-21 '
#                                                           '13:16:26'}}
#
#
# The full value of perf_summary is:
# {'listings_join_review_2009': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.6709,
#                                                                            'min': 0.6376,
#                                                                            'max': 0.7043,
#                                                                            'std': 0.0334,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:24'},
#                                '__datetime_in_reviews__': {'avg': 0.1036,
#                                                            'min': 0.0784,
#                                                            'max': 0.1288,
#                                                            'std': 0.0252,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:25'},
#                                '__id_in_listings__': {'avg': 0.0801,
#                                                       'min': 0.0737,
#                                                       'max': 0.0865,
#                                                       'std': 0.0064,
#                                                       'exec_count': 2,
#                                                       'timestamp': '2024-05-21 '
#                                                                    '13:16:26'},
#                                '__': {'avg': 0.076,
#                                       'min': 0.0756,
#                                       'max': 0.0763,
#                                       'std': 0.0004,
#                                       'exec_count': 2,
#                                       'timestamp': '2024-05-21 13:16:26'}},
#  'listings_join_review_2010': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.0745,
#                                                                            'min': 0.0744,
#                                                                            'max': 0.0747,
#                                                                            'std': 0.0002,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:26'}}}
# Processing spec:  [['datetime', 'reviews']]
#
#
# After dropping ['id', 'listings']
#
# After adding ['datetime', 'reviews']
#
# The list of running times is as follows:
# [0.078581, 0.077671]
#
# The statistics on the list of running times are as follows:
# {'avg': 0.0781,
#  'min': 0.0777,
#  'max': 0.0786,
#  'std': 0.0005,
#  'exec_count': 2,
#  'timestamp': '2024-05-21 13:16:27'}
#
# The new value for "__datetime_in_reviews__" will be {'avg': 0.0781, 'min': 0.0777, 'max': 0.0786, 'std': 0.0005, 'exec_count': 2, 'timestamp': '2024-05-21 13:16:27'}
#
# Before modifying perf_dict, the value of perf_summary[query_name] (if it existed) was:
# {'__datetime_in_reviews__id_in_listings__': {'avg': 0.0745,
#                                              'min': 0.0744,
#                                              'max': 0.0747,
#                                              'std': 0.0002,
#                                              'exec_count': 2,
#                                              'timestamp': '2024-05-21 '
#                                                           '13:16:26'}}
#
#
# After modifying perf_dict, the value of perf_summary[query_name] is:
# {'__datetime_in_reviews__id_in_listings__': {'avg': 0.0745,
#                                              'min': 0.0744,
#                                              'max': 0.0747,
#                                              'std': 0.0002,
#                                              'exec_count': 2,
#                                              'timestamp': '2024-05-21 '
#                                                           '13:16:26'},
#  '__datetime_in_reviews__': {'avg': 0.0781,
#                              'min': 0.0777,
#                              'max': 0.0786,
#                              'std': 0.0005,
#                              'exec_count': 2,
#                              'timestamp': '2024-05-21 13:16:27'}}
#
#
# The full value of perf_summary is:
# {'listings_join_review_2009': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.6709,
#                                                                            'min': 0.6376,
#                                                                            'max': 0.7043,
#                                                                            'std': 0.0334,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:24'},
#                                '__datetime_in_reviews__': {'avg': 0.1036,
#                                                            'min': 0.0784,
#                                                            'max': 0.1288,
#                                                            'std': 0.0252,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:25'},
#                                '__id_in_listings__': {'avg': 0.0801,
#                                                       'min': 0.0737,
#                                                       'max': 0.0865,
#                                                       'std': 0.0064,
#                                                       'exec_count': 2,
#                                                       'timestamp': '2024-05-21 '
#                                                                    '13:16:26'},
#                                '__': {'avg': 0.076,
#                                       'min': 0.0756,
#                                       'max': 0.0763,
#                                       'std': 0.0004,
#                                       'exec_count': 2,
#                                       'timestamp': '2024-05-21 13:16:26'}},
#  'listings_join_review_2010': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.0745,
#                                                                            'min': 0.0744,
#                                                                            'max': 0.0747,
#                                                                            'std': 0.0002,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:26'},
#                                '__datetime_in_reviews__': {'avg': 0.0781,
#                                                            'min': 0.0777,
#                                                            'max': 0.0786,
#                                                            'std': 0.0005,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:27'}}}
# Processing spec:  [['id', 'listings']]
#
#
# After dropping ['datetime', 'reviews']
#
# After adding ['id', 'listings']
#
# The list of running times is as follows:
# [0.078279, 0.07658]
#
# The statistics on the list of running times are as follows:
# {'avg': 0.0774,
#  'min': 0.0766,
#  'max': 0.0783,
#  'std': 0.0008,
#  'exec_count': 2,
#  'timestamp': '2024-05-21 13:16:27'}
#
# The new value for "__id_in_listings__" will be {'avg': 0.0774, 'min': 0.0766, 'max': 0.0783, 'std': 0.0008, 'exec_count': 2, 'timestamp': '2024-05-21 13:16:27'}
#
# Before modifying perf_dict, the value of perf_summary[query_name] (if it existed) was:
# {'__datetime_in_reviews__id_in_listings__': {'avg': 0.0745,
#                                              'min': 0.0744,
#                                              'max': 0.0747,
#                                              'std': 0.0002,
#                                              'exec_count': 2,
#                                              'timestamp': '2024-05-21 '
#                                                           '13:16:26'},
#  '__datetime_in_reviews__': {'avg': 0.0781,
#                              'min': 0.0777,
#                              'max': 0.0786,
#                              'std': 0.0005,
#                              'exec_count': 2,
#                              'timestamp': '2024-05-21 13:16:27'}}
#
#
# After modifying perf_dict, the value of perf_summary[query_name] is:
# {'__datetime_in_reviews__id_in_listings__': {'avg': 0.0745,
#                                              'min': 0.0744,
#                                              'max': 0.0747,
#                                              'std': 0.0002,
#                                              'exec_count': 2,
#                                              'timestamp': '2024-05-21 '
#                                                           '13:16:26'},
#  '__datetime_in_reviews__': {'avg': 0.0781,
#                              'min': 0.0777,
#                              'max': 0.0786,
#                              'std': 0.0005,
#                              'exec_count': 2,
#                              'timestamp': '2024-05-21 13:16:27'},
#  '__id_in_listings__': {'avg': 0.0774,
#                         'min': 0.0766,
#                         'max': 0.0783,
#                         'std': 0.0008,
#                         'exec_count': 2,
#                         'timestamp': '2024-05-21 13:16:27'}}
#
#
# The full value of perf_summary is:
# {'listings_join_review_2009': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.6709,
#                                                                            'min': 0.6376,
#                                                                            'max': 0.7043,
#                                                                            'std': 0.0334,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:24'},
#                                '__datetime_in_reviews__': {'avg': 0.1036,
#                                                            'min': 0.0784,
#                                                            'max': 0.1288,
#                                                            'std': 0.0252,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:25'},
#                                '__id_in_listings__': {'avg': 0.0801,
#                                                       'min': 0.0737,
#                                                       'max': 0.0865,
#                                                       'std': 0.0064,
#                                                       'exec_count': 2,
#                                                       'timestamp': '2024-05-21 '
#                                                                    '13:16:26'},
#                                '__': {'avg': 0.076,
#                                       'min': 0.0756,
#                                       'max': 0.0763,
#                                       'std': 0.0004,
#                                       'exec_count': 2,
#                                       'timestamp': '2024-05-21 13:16:26'}},
#  'listings_join_review_2010': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.0745,
#                                                                            'min': 0.0744,
#                                                                            'max': 0.0747,
#                                                                            'std': 0.0002,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:26'},
#                                '__datetime_in_reviews__': {'avg': 0.0781,
#                                                            'min': 0.0777,
#                                                            'max': 0.0786,
#                                                            'std': 0.0005,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:27'},
#                                '__id_in_listings__': {'avg': 0.0774,
#                                                       'min': 0.0766,
#                                                       'max': 0.0783,
#                                                       'std': 0.0008,
#                                                       'exec_count': 2,
#                                                       'timestamp': '2024-05-21 '
#                                                                    '13:16:27'}}}
# Processing spec:  []
#
#
# After dropping ['datetime', 'reviews']
#
# After dropping ['id', 'listings']
#
# The list of running times is as follows:
# [0.078137, 0.079723]
#
# The statistics on the list of running times are as follows:
# {'avg': 0.0789,
#  'min': 0.0781,
#  'max': 0.0797,
#  'std': 0.0008,
#  'exec_count': 2,
#  'timestamp': '2024-05-21 13:16:27'}
#
# The new value for "__" will be {'avg': 0.0789, 'min': 0.0781, 'max': 0.0797, 'std': 0.0008, 'exec_count': 2, 'timestamp': '2024-05-21 13:16:27'}
#
# Before modifying perf_dict, the value of perf_summary[query_name] (if it existed) was:
# {'__datetime_in_reviews__id_in_listings__': {'avg': 0.0745,
#                                              'min': 0.0744,
#                                              'max': 0.0747,
#                                              'std': 0.0002,
#                                              'exec_count': 2,
#                                              'timestamp': '2024-05-21 '
#                                                           '13:16:26'},
#  '__datetime_in_reviews__': {'avg': 0.0781,
#                              'min': 0.0777,
#                              'max': 0.0786,
#                              'std': 0.0005,
#                              'exec_count': 2,
#                              'timestamp': '2024-05-21 13:16:27'},
#  '__id_in_listings__': {'avg': 0.0774,
#                         'min': 0.0766,
#                         'max': 0.0783,
#                         'std': 0.0008,
#                         'exec_count': 2,
#                         'timestamp': '2024-05-21 13:16:27'}}
#
#
# After modifying perf_dict, the value of perf_summary[query_name] is:
# {'__datetime_in_reviews__id_in_listings__': {'avg': 0.0745,
#                                              'min': 0.0744,
#                                              'max': 0.0747,
#                                              'std': 0.0002,
#                                              'exec_count': 2,
#                                              'timestamp': '2024-05-21 '
#                                                           '13:16:26'},
#  '__datetime_in_reviews__': {'avg': 0.0781,
#                              'min': 0.0777,
#                              'max': 0.0786,
#                              'std': 0.0005,
#                              'exec_count': 2,
#                              'timestamp': '2024-05-21 13:16:27'},
#  '__id_in_listings__': {'avg': 0.0774,
#                         'min': 0.0766,
#                         'max': 0.0783,
#                         'std': 0.0008,
#                         'exec_count': 2,
#                         'timestamp': '2024-05-21 13:16:27'},
#  '__': {'avg': 0.0789,
#         'min': 0.0781,
#         'max': 0.0797,
#         'std': 0.0008,
#         'exec_count': 2,
#         'timestamp': '2024-05-21 13:16:27'}}
#
#
# The full value of perf_summary is:
# {'listings_join_review_2009': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.6709,
#                                                                            'min': 0.6376,
#                                                                            'max': 0.7043,
#                                                                            'std': 0.0334,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:24'},
#                                '__datetime_in_reviews__': {'avg': 0.1036,
#                                                            'min': 0.0784,
#                                                            'max': 0.1288,
#                                                            'std': 0.0252,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:25'},
#                                '__id_in_listings__': {'avg': 0.0801,
#                                                       'min': 0.0737,
#                                                       'max': 0.0865,
#                                                       'std': 0.0064,
#                                                       'exec_count': 2,
#                                                       'timestamp': '2024-05-21 '
#                                                                    '13:16:26'},
#                                '__': {'avg': 0.076,
#                                       'min': 0.0756,
#                                       'max': 0.0763,
#                                       'std': 0.0004,
#                                       'exec_count': 2,
#                                       'timestamp': '2024-05-21 13:16:26'}},
#  'listings_join_review_2010': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.0745,
#                                                                            'min': 0.0744,
#                                                                            'max': 0.0747,
#                                                                            'std': 0.0002,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:26'},
#                                '__datetime_in_reviews__': {'avg': 0.0781,
#                                                            'min': 0.0777,
#                                                            'max': 0.0786,
#                                                            'std': 0.0005,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:27'},
#                                '__id_in_listings__': {'avg': 0.0774,
#                                                       'min': 0.0766,
#                                                       'max': 0.0783,
#                                                       'std': 0.0008,
#                                                       'exec_count': 2,
#                                                       'timestamp': '2024-05-21 '
#                                                                    '13:16:27'},
#                                '__': {'avg': 0.0789,
#                                       'min': 0.0781,
#                                       'max': 0.0797,
#                                       'std': 0.0008,
#                                       'exec_count': 2,
#                                       'timestamp': '2024-05-21 13:16:27'}}}
# Processing spec:  [['datetime', 'reviews'], ['id', 'listings']]
#
#
# After adding ['datetime', 'reviews']
#
# After adding ['id', 'listings']
#
# The list of running times is as follows:
# [0.079027, 0.076432]
#
# The statistics on the list of running times are as follows:
# {'avg': 0.0777,
#  'min': 0.0764,
#  'max': 0.079,
#  'std': 0.0013,
#  'exec_count': 2,
#  'timestamp': '2024-05-21 13:16:27'}
#
# The new value for "__datetime_in_reviews__id_in_listings__" will be {'avg': 0.0777, 'min': 0.0764, 'max': 0.079, 'std': 0.0013, 'exec_count': 2, 'timestamp': '2024-05-21 13:16:27'}
#
# Before modifying perf_dict, the value of perf_summary[query_name] had empty value
#
#
# After modifying perf_dict, the value of perf_summary[query_name] is:
# {'__datetime_in_reviews__id_in_listings__': {'avg': 0.0777,
#                                              'min': 0.0764,
#                                              'max': 0.079,
#                                              'std': 0.0013,
#                                              'exec_count': 2,
#                                              'timestamp': '2024-05-21 '
#                                                           '13:16:27'}}
#
#
# The full value of perf_summary is:
# {'listings_join_review_2009': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.6709,
#                                                                            'min': 0.6376,
#                                                                            'max': 0.7043,
#                                                                            'std': 0.0334,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:24'},
#                                '__datetime_in_reviews__': {'avg': 0.1036,
#                                                            'min': 0.0784,
#                                                            'max': 0.1288,
#                                                            'std': 0.0252,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:25'},
#                                '__id_in_listings__': {'avg': 0.0801,
#                                                       'min': 0.0737,
#                                                       'max': 0.0865,
#                                                       'std': 0.0064,
#                                                       'exec_count': 2,
#                                                       'timestamp': '2024-05-21 '
#                                                                    '13:16:26'},
#                                '__': {'avg': 0.076,
#                                       'min': 0.0756,
#                                       'max': 0.0763,
#                                       'std': 0.0004,
#                                       'exec_count': 2,
#                                       'timestamp': '2024-05-21 13:16:26'}},
#  'listings_join_review_2010': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.0745,
#                                                                            'min': 0.0744,
#                                                                            'max': 0.0747,
#                                                                            'std': 0.0002,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:26'},
#                                '__datetime_in_reviews__': {'avg': 0.0781,
#                                                            'min': 0.0777,
# ...
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:36'},
#                                '__datetime_in_reviews__': {'avg': 0.0874,
#                                                            'min': 0.0873,
#                                                            'max': 0.0875,
#                                                            'std': 0.0001,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:36'},
#                                '__id_in_listings__': {'avg': 0.0875,
#                                                       'min': 0.0868,
#                                                       'max': 0.0882,
#                                                       'std': 0.0007,
#                                                       'exec_count': 2,
#                                                       'timestamp': '2024-05-21 '
#                                                                    '13:16:37'},
#                                '__': {'avg': 0.0903,
#                                       'min': 0.0859,
#                                       'max': 0.0946,
#                                       'std': 0.0044,
#                                       'exec_count': 2,
#                                       'timestamp': '2024-05-21 13:16:37'}},
#  'listings_join_review_2018': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.197,
#                                                                            'min': 0.1804,
#                                                                            'max': 0.2137,
#                                                                            'std': 0.0167,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:38'},
#                                '__datetime_in_reviews__': {'avg': 0.2062,
#                                                            'min': 0.1837,
#                                                            'max': 0.2288,
#                                                            'std': 0.0225,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:38'},
#                                '__id_in_listings__': {'avg': 0.1986,
#                                                       'min': 0.1804,
#                                                       'max': 0.2167,
#                                                       'std': 0.0181,
#                                                       'exec_count': 2,
#                                                       'timestamp': '2024-05-21 '
#                                                                    '13:16:39'},
#                                '__': {'avg': 0.1953,
#                                       'min': 0.1917,
#                                       'max': 0.1989,
#                                       'std': 0.0036,
#                                       'exec_count': 2,
#                                       'timestamp': '2024-05-21 13:16:39'}},
#  'listings_join_review_2019': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.1929,
#                                                                            'min': 0.1918,
#                                                                            'max': 0.1941,
#                                                                            'std': 0.0011,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:40'},
#                                '__datetime_in_reviews__': {'avg': 0.1923,
#                                                            'min': 0.1883,
#                                                            'max': 0.1963,
#                                                            'std': 0.004,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:41'},
#                                '__id_in_listings__': {'avg': 0.1982,
#                                                       'min': 0.1935,
#                                                       'max': 0.2029,
#                                                       'std': 0.0047,
#                                                       'exec_count': 2,
#                                                       'timestamp': '2024-05-21 '
#                                                                    '13:16:41'},
#                                '__': {'avg': 0.184,
#                                       'min': 0.1838,
#                                       'max': 0.1843,
#                                       'std': 0.0002,
#                                       'exec_count': 2,
#                                       'timestamp': '2024-05-21 13:16:41'}},
#  'listings_join_review_2020': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.0924,
#                                                                            'min': 0.0891,
#                                                                            'max': 0.0957,
#                                                                            'std': 0.0033,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:42'},
#                                '__datetime_in_reviews__': {'avg': 0.0924,
#                                                            'min': 0.09,
#                                                            'max': 0.0947,
#                                                            'std': 0.0023,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:43'},
#                                '__id_in_listings__': {'avg': 0.0994,
#                                                       'min': 0.0959,
#                                                       'max': 0.1028,
#                                                       'std': 0.0035,
#                                                       'exec_count': 2,
#                                                       'timestamp': '2024-05-21 '
#                                                                    '13:16:43'},
#                                '__': {'avg': 0.1458,
#                                       'min': 0.0966,
#                                       'max': 0.195,
#                                       'std': 0.0492,
#                                       'exec_count': 2,
#                                       'timestamp': '2024-05-21 13:16:43'}},
#  'listings_join_review_2021': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.2027,
#                                                                            'min': 0.1916,
#                                                                            'max': 0.2139,
#                                                                            'std': 0.0112,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:44'},
#                                '__datetime_in_reviews__': {'avg': 0.197,
#                                                            'min': 0.1967,
#                                                            'max': 0.1972,
#                                                            'std': 0.0003,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:45'},
#                                '__id_in_listings__': {'avg': 0.1862,
#                                                       'min': 0.182,
#                                                       'max': 0.1904,
#                                                       'std': 0.0042,
#                                                       'exec_count': 2,
#                                                       'timestamp': '2024-05-21 '
#                                                                    '13:16:45'},
#                                '__': {'avg': 0.2031,
#                                       'min': 0.2022,
#                                       'max': 0.2039,
#                                       'std': 0.0008,
#                                       'exec_count': 2,
#                                       'timestamp': '2024-05-21 13:16:45'}},
#  'listings_join_review_2022': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.1151,
#                                                                            'min': 0.1019,
#                                                                            'max': 0.1282,
#                                                                            'std': 0.0132,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:46'},
#                                '__datetime_in_reviews__': {'avg': 0.1585,
#                                                            'min': 0.122,
#                                                            'max': 0.195,
#                                                            'std': 0.0365,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:47'},
#                                '__id_in_listings__': {'avg': 0.1219,
#                                                       'min': 0.1052,
#                                                       'max': 0.1386,
#                                                       'std': 0.0167,
#                                                       'exec_count': 2,
#                                                       'timestamp': '2024-05-21 '
#                                                                    '13:16:47'},
#                                '__': {'avg': 0.1015,
#                                       'min': 0.1001,
#                                       'max': 0.1029,
#                                       'std': 0.0014,
#                                       'exec_count': 2,
#                                       'timestamp': '2024-05-21 13:16:47'}},
#  'listings_join_review_2023': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.1075,
#                                                                            'min': 0.1067,
#                                                                            'max': 0.1083,
#                                                                            'std': 0.0008,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:48'},
#                                '__datetime_in_reviews__': {'avg': 0.1071,
#                                                            'min': 0.105,
#                                                            'max': 0.1092,
#                                                            'std': 0.0021,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:48'},
#                                '__id_in_listings__': {'avg': 0.1139,
#                                                       'min': 0.1063,
#                                                       'max': 0.1214,
#                                                       'std': 0.0076,
#                                                       'exec_count': 2,
#                                                       'timestamp': '2024-05-21 '
#                                                                    '13:16:48'},
#                                '__': {'avg': 0.1062,
#                                       'min': 0.1045,
#                                       'max': 0.108,
#                                       'std': 0.0017,
#                                       'exec_count': 2,
#                                       'timestamp': '2024-05-21 13:16:49'}},
#  'listings_join_review_2024': {'__datetime_in_reviews__id_in_listings__': {'avg': 0.0769,
#                                                                            'min': 0.0768,
#                                                                            'max': 0.0769,
#                                                                            'std': 0.0001,
#                                                                            'exec_count': 2,
#                                                                            'timestamp': '2024-05-21 '
#                                                                                         '13:16:49'},
#                                '__datetime_in_reviews__': {'avg': 0.0765,
#                                                            'min': 0.0756,
#                                                            'max': 0.0774,
#                                                            'std': 0.0009,
#                                                            'exec_count': 2,
#                                                            'timestamp': '2024-05-21 '
#                                                                         '13:16:50'},
#                                '__id_in_listings__': {'avg': 0.0785,
#                                                       'min': 0.0766,
#                                                       'max': 0.0804,
#                                                       'std': 0.0019,
#                                                       'exec_count': 2,
#                                                       'timestamp': '2024-05-21 '
#                                                                    '13:16:50'},
#                                '__': {'avg': 0.077,
#                                       'min': 0.0759,
#                                       'max': 0.078,
#                                       'std': 0.0011,
#                                       'exec_count': 2,
#                                       'timestamp': '2024-05-21 13:16:50'}}}
# JSON files created successfully.
